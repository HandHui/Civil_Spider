# %%
from selenium import webdriver

# %%
import time

# %%
import urllib

# %%
browser = webdriver.Firefox(log_path = "webdriver.log")

browser.get('http://www.hshfy.sh.cn/shfy/gweb2017/flws_list.jsp?ajlb=aYWpsYj3D8crCz#a')
time.sleep(0.5)


# name=driver.find_element_by_id("username")#定位账号输入框
# password=driver.find_element_by_id("password_1")#定位密码输入框
code1=browser.find_element_by_id("imageCode")#定位验证码输入框

src = browser.find_element_by_id("imageCode").get_attribute('src')
print(src)
# data = urllib.request.urlopen(src).read()
# print(data)

urllib.request.urlretrieve(src, 'code.do.jpeg')



print(code1)
# browser.save_screenshot("01.png")

print(browser.page_source)
# browser.close()
# Out:
# /home/song/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: use service_log_path instead of log_path
#   """Entry point for launching an IPython kernel.
# http://www.hshfy.sh.cn/shfy/code.do?n=0.22608186392936713
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="ec37d65d-77b9-4929-8d63-b4eb798b7c59", element="b1e321ac-a5ae-46aa-a8b5-c027db2be2a6")>
# <html xmlns="http://www.w3.org/1999/xhtml"><head>
# 			<meta http-equiv="Content-Type" content="text/html; charset=gbk">
# 			<title>上海市高级人民法院--裁判文书</title>
# 			<link href="images2014/css.css" rel="stylesheet" type="text/css">
# 			<link href="images2014/default.css" rel="stylesheet" type="text/css">
# ...

# %%
browser = webdriver.Firefox(log_path = "webdriver.log")

browser.get('http://www.hshfy.sh.cn/shfy/gweb2017/flws_list.jsp?ajlb=aYWpsYj3D8crCz#a')
time.sleep(0.5)


# name=driver.find_element_by_id("username")#定位账号输入框
# password=driver.find_element_by_id("password_1")#定位密码输入框
code1=browser.find_element_by_id("imageCode")#定位验证码输入框

code = input()
code1.send_keys(code)#给定位验证码的输入框中输入读取到的验证码
click=driver.find_element_by_name("yt0").click()#点击登录

# src = browser.find_element_by_id("imageCode").get_attribute('src')
# print(src)
# # data = urllib.request.urlopen(src).read()
# # print(data)

# urllib.request.urlretrieve(src, 'code.do.jpeg')



# print(code1)
# browser.save_screenshot("01.png")

print(browser.page_source)
# browser.close()
# Out:
# /home/song/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: use service_log_path instead of log_path
#   """Entry point for launching an IPython kernel.
# rd61
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-37-f061e92ff1c0> in <module>
#      10
#      11 code = input()
# ---> 12 code1.send_keys(code)#给定位验证码的输入框中输入读取到的验证码
#      13 click=driver.find_element_by_name("yt0").click()#点击登录
#      14
#
# ~/.local/lib/python3.5/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
# --> 479                        'value': keys_to_typing(value)})
#     480
#     481     # RenderedWebElement Items
#
# ...
