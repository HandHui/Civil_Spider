# %%
from selenium import webdriver

# %%
browser = webdriver.Firefox(log_path = "webdriver.log")

browser.get("http://wenshu.court.gov.cn/List/List?sorttype=1&conditions=searchWord+2+AJLX++%E6%A1%88%E4%BB%B6%E7%B1%BB%E5%9E%8B:%E6%B0%91%E4%BA%8B%E6%A1%88%E4%BB%B6")
print(browser.page_source)
browser.close()
# Out:
# /home/song/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: use service_log_path instead of log_path
#   """Entry point for launching an IPython kernel.
# <html xmlns="http://www.w3.org/1999/xhtml" style="overflow-x: hidden;"><head id="Head1"><meta http-equiv="X-UA-Compatible" content="IE=8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta http-equiv="X-UA-Compatible" content="IE=EmulateIE8"><title>
# 	列表页 - 中国裁判文书网
# </title><link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"><link rel="bookmark" href="/favicon.ico" type="image/x-icon"><link href="/Assets/css/User.css" rel="stylesheet" type="text/css"><link href="/Assets/css/List.css" rel="stylesheet" type="text/css">
# ...
